# %% [markdown]
# # Imports

# %%
import os

import pandas as pd
import scanpy

def describe(df, random=False):
    print(df.shape)
    print("--- First 5 entries ---")
    display(df.head())
    if random:
        print('--- Random subset ---')
        display(df.sample(5))
        
data_folder = '/home/olga/data_lg/data_sm_copy/tabula-microcebus/data-objects/ss2-10x-combined'

# %%
lemur_new_metadata = pd.read_csv(
    os.path.join(data_folder, "LCA_SS2_10x_all_metadata_update.csv"), index_col=0
)
describe(lemur_new_metadata)
# Out:
# (244081, 18)
# --- First 5 entries ---
# /home/olga/miniconda3/envs/tabula-microcebus-v2/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3051: DtypeWarning: Columns (9,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                            nCount_RNA  nFeature_RNA  \
# MAA001519_B108948_A10_S10     2467361          2526
# MAA001519_B108948_A11_S11     2489227          2764
# MAA001519_B108948_A12_S12     2267728          7156
# MAA001519_B108948_A13_S13     1663223          3401
# MAA001519_B108948_A14_S14     1410159          8500
#
#                                        cell_name_old  \
# MAA001519_B108948_A10_S10  MAA001519_B108948_A10_S10
# MAA001519_B108948_A11_S11  MAA001519_B108948_A11_S11
# MAA001519_B108948_A12_S12  MAA001519_B108948_A12_S12
# MAA001519_B108948_A13_S13  MAA001519_B108948_A13_S13
# MAA001519_B108948_A14_S14  MAA001519_B108948_A14_S14
#
#                                     cell_name_update cell_barcode_10x  \
# MAA001519_B108948_A10_S10  MAA001519_B108948_A10_S10              NaN
# MAA001519_B108948_A11_S11  MAA001519_B108948_A11_S11              NaN
# MAA001519_B108948_A12_S12  MAA001519_B108948_A12_S12              NaN
# MAA001519_B108948_A13_S13  MAA001519_B108948_A13_S13              NaN
# MAA001519_B108948_A14_S14  MAA001519_B108948_A14_S14              NaN
#
#                           sequencing_run_10x channel_update_10x  batch_SS2  \
# MAA001519_B108948_A10_S10                NaN                NaN          0
# MAA001519_B108948_A11_S11                NaN                NaN          0
# MAA001519_B108948_A12_S12                NaN                NaN          0
# MAA001519_B108948_A13_S13                NaN                NaN          0
# MAA001519_B108948_A14_S14                NaN                NaN          0
#
#                           possibly_contaminated_barcode_10x     method  \
# MAA001519_B108948_A10_S10                               NaN  smartseq2
# MAA001519_B108948_A11_S11                               NaN  smartseq2
# MAA001519_B108948_A12_S12                               NaN  smartseq2
# MAA001519_B108948_A13_S13                               NaN  smartseq2
# MAA001519_B108948_A14_S14                               NaN  smartseq2
#
#                           individual tissue_update subtissue_update  \
# MAA001519_B108948_A10_S10    Antoine        Testes              NaN
# MAA001519_B108948_A11_S11    Antoine        Testes              NaN
# MAA001519_B108948_A12_S12    Antoine        Testes              NaN
# MAA001519_B108948_A13_S13    Antoine        Testes              NaN
# MAA001519_B108948_A14_S14    Antoine        Testes              NaN
#
#                           compartment_update cell_ontology_class_update  \
# MAA001519_B108948_A10_S10               germ                  spermatid
# MAA001519_B108948_A11_S11               germ                  spermatid
# MAA001519_B108948_A12_S12               germ               spermatocyte
# MAA001519_B108948_A13_S13               germ                  spermatid
# MAA001519_B108948_A14_S14               germ               spermatocyte
#
#                            free_annotation_update  \
# MAA001519_B108948_A10_S10    elongating spermatid
# MAA001519_B108948_A11_S11    elongating spermatid
# MAA001519_B108948_A12_S12  pachytene spermatocyte
# Diaphragm                    78
# Name: tissue_update, dtype: int64

# %%
sorted(lemur_new_metadata_tenx.query('tissue_update == "Limb_muscle"')['free_annotation_update'].unique())
# Out:
# ['B cell',
#  'B cell (PF)',
#  'T cell (CD4+ CD8- CCL5- CLDN1+)',
#  'T cell (CD4+ CD8- CCL5-)',
#  'T cell (CD4- CD8+ CCL5+)',
#  'T cell (CD4- CD8+ CCL5-)',
#  'adipocyte (UCP1lo)',
#  'artery cell',
#  'basophil',
#  'capillary cell (CX3CL1+)',
#  'capillary cell (FABP4+ RBP7+)',
#  'capillary cell (FABP4+ RBP7lo)',
#  'doublets_endothelial_immune',
#  'doublets_endothelial_stromal',
#  'doublets_erythroid-megakaryocyte_stromal',
#  'doublets_immune_stromal',
#  'erythroid lineage cell',
#  'fast muscle cell',
#  'fibroadipogenic progenitor cell_fibroblast',
#  'lymphatic cell (CCDC80+)',
#  'lymphatic cell (CCL21+)',
#  'macrophage',
#  'natural killer T cell',
#  'natural killer cell_T cell (PF)',
#  'neutrophil',
#  'pericyte cell',
#  'plasma cell',
#  'plasma cell (PF)',
#  'reticular cell',
#  'skeletal muscle satellite stem cell',
#  'slow muscle cell',
#  'tendon cell',
#  'vascular associated smooth muscle cell',
#  'vein cell']

# %%
# %%time

h5ad = os.path.join(data_folder, "LCA_SS2_10x_all_update.h5ad")
lemur = scanpy.read(h5ad, cache=True)
lemur
# Out:
# CPU times: user 1.09 s, sys: 2.31 s, total: 3.4 s
# Wall time: 16.1 s
# AnnData object with n_obs × n_vars = 244081 × 31509
#     obs: 'nCount_RNA', 'nFeature_RNA', 'cell_name_old', 'cell_name_update', 'cell_barcode_10x', 'sequencing_run_10x', 'channel_update_10x', 'batch_SS2', 'possibly_contaminated_barcode_10x', 'method', 'individual', 'tissue_update', 'subtissue_update', 'compartment_update', 'cell_ontology_class_update', 'free_annotation_update', 'tissue__free_annotation_update', 'tissue__cell_ontology_class_update'
#     var: 'name', 'highly_variable'
#     uns: 'compartment_update_colors'
#     obsm: 'X_pca', 'X_umap'

# %% [markdown]
# ## Remove `_update` from columns

# %%
lemur.obs.columns = lemur.obs.columns.str.split('_update').str[0]
lemur
# Out:
# AnnData object with n_obs × n_vars = 244081 × 31509
#     obs: 'nCount_RNA', 'nFeature_RNA', 'cell_name_old', 'cell_name', 'cell_barcode_10x', 'sequencing_run_10x', 'channel', 'batch_SS2', 'possibly_contaminated_barcode_10x', 'method', 'individual', 'tissue', 'subtissue', 'compartment', 'cell_ontology_class', 'free_annotation', 'tissue__free_annotation', 'tissue__cell_ontology_class'
#     var: 'name', 'highly_variable'
#     uns: 'compartment_update_colors'
#     obsm: 'X_pca', 'X_umap'

# %% [markdown]
# ## Add "mouse lemur" to species

# %%
lemur.obs['species'] = 'Mouse lemur'
lemur.obs['species_latin'] = 'Microcebus murinus'
lemur.obs.head()
# Out:
#                            nCount_RNA  nFeature_RNA  \
# MAA001519_B108948_A10_S10     2467361          2526
# MAA001519_B108948_A11_S11     2489227          2764
# MAA001519_B108948_A12_S12     2267728          7156
# MAA001519_B108948_A13_S13     1663223          3401
# MAA001519_B108948_A14_S14     1410159          8500
# MAA001519_B108948_A11_S11  Microcebus murinus
# MAA001519_B108948_A12_S12  Microcebus murinus
# MAA001519_B108948_A13_S13  Microcebus murinus
# MAA001519_B108948_A14_S14  Microcebus murinus

# %%
lemur.var.head()
# Out:
#                   name  highly_variable
# AU129-gt01  AU129-gt01            False
# AU129-gr02  AU129-gr02             True
# AU129-gt02  AU129-gt02            False
# AU129-gr01  AU129-gr01             True
# AU129-gt03  AU129-gt03            False

# %%
scanpy.pl.umap(lemur, color=['compartment', 'tissue', 'individual', 'method'])
# Out:
# ... storing 'species' as categorical
# ... storing 'species_latin' as categorical
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
lemur_tenx = lemur[lemur_new_metadata_tenx.index]
lemur_tenx
# Out:
# View of AnnData object with n_obs × n_vars = 231752 × 31509
#     obs: 'nCount_RNA', 'nFeature_RNA', 'cell_name_old', 'cell_name', 'cell_barcode_10x', 'sequencing_run_10x', 'channel', 'batch_SS2', 'possibly_contaminated_barcode_10x', 'method', 'individual', 'tissue', 'subtissue', 'compartment', 'cell_ontology_class', 'free_annotation', 'tissue__free_annotation', 'tissue__cell_ontology_class', 'species', 'species_latin'
#     var: 'name', 'highly_variable'
#     uns: 'compartment_update_colors', 'compartment_colors', 'tissue_colors', 'individual_colors', 'method_colors'
#     obsm: 'X_pca', 'X_umap'

# %%
sorted(lemur_tenx.obs.columns)
# Out:
# ['batch_SS2',
#  'cell_barcode_10x',
#  'cell_name',
#  'cell_name_old',
#  'cell_ontology_class',
#  'channel',
#  'compartment',
#  'free_annotation',
#  'individual',
#  'method',
#  'nCount_RNA',
#  'nFeature_RNA',
#  'possibly_contaminated_barcode_10x',
#  'sequencing_run_10x',
#  'species',
#  'species_latin',
#  'subtissue',
#  'tissue',
#  'tissue__cell_ontology_class',
#  'tissue__free_annotation']

# %% [markdown]
# ## Add sex and age

# %%
sex_mapper = {
    "Martine": "female",
    "Stumpy": "female",
    "Bernard": "male",
    "Antoine": "male",
}

age_mapper = {
    "Martine": "12y",
    "Stumpy": "10y",
    "Bernard": "9y",
    "Antoine": "12y",
}

lemur_tenx.obs["sex"] = lemur_tenx.obs.individual.map(sex_mapper)
lemur_tenx.obs["age"] = lemur_tenx.obs.individual.map(age_mapper)
# Out:
# Trying to set attribute `.obs` of view, copying.

# %% [markdown]
# ## Add lemur number to individual name

# %%
lemur_to_number = dict(zip(sorted(lemur_tenx.obs.individual.unique()), range(1, 5)))
lemur_to_number
# Out:
# {'Antoine': 1, 'Bernard': 2, 'Martine': 3, 'Stumpy': 4}

# %%
lemur_tenx.obs['individual_v2'] = lemur_tenx.obs.individual.map(lambda x: f"lemur_{lemur_to_number[x]}_{x}")
lemur_tenx.obs['individual_v2'].value_counts()
# Out:
# lemur_1_Antoine    96842
# lemur_4_Stumpy     83716
# lemur_3_Martine    30753
# lemur_2_Bernard    20441
# Name: individual_v2, dtype: int64

# %% [markdown]
# # Write to file

# %%
h5ad = os.path.join(data_folder, "LCA_10x_update.h5ad")
lemur_tenx.write(h5ad)
# Out:
# ... storing 'sex' as categorical
# ... storing 'age' as categorical

# %%
lemur_tenx
# Out:
# AnnData object with n_obs × n_vars = 231752 × 31509
#     obs: 'nCount_RNA', 'nFeature_RNA', 'cell_name_old', 'cell_name', 'cell_barcode_10x', 'sequencing_run_10x', 'channel', 'batch_SS2', 'possibly_contaminated_barcode_10x', 'method', 'individual', 'tissue', 'subtissue', 'compartment', 'cell_ontology_class', 'free_annotation', 'tissue__free_annotation', 'tissue__cell_ontology_class', 'species', 'species_latin', 'sex', 'age', 'individual_v2'
#     var: 'name', 'highly_variable'
#     uns: 'compartment_update_colors', 'compartment_colors', 'tissue_colors', 'individual_colors', 'method_colors'
#     obsm: 'X_pca', 'X_umap'

# %% [markdown]
# # Add unified cell type groups

# %% [markdown]
# ## Use minimal obs columns

# %%
obs_minimal = lemur_tenx.obs.rename(columns={'batch_SS2': None,
 'cell_barcode_10x': 'cell_barcode',
 'cell_name': 'cell_id_v2',
 'cell_name_old': 'cell_id_v1',
 'cell_ontology_class': 'cell_ontology_class',
 'channel': 'channel',
 'compartment': None,
 'free_annotation': 'free_annotation',
 'individual': None,
 'individual_v2': 'individual',
 'method': None,
 'nCount_RNA': 'n_counts',
 'nFeature_RNA': 'n_genes',
 'possibly_contaminated_barcode_10x': None,
 'sequencing_run_10x': 'sequencing_run',
 'species': 'species',
 'species_latin': 'species_latin',
 'subtissue': 'subtissue',
 'tissue': 'tissue',
 'tissue__cell_ontology_class': None,
 'tissue__free_annotation': None})
obs_minimal = obs_minimal.loc[:, obs_minimal.columns.notnull()]
print(obs_minimal.shape)
obs_minimal.head()
# Out:
# (231752, 16)
#                                      n_counts  n_genes  \
# Antoine_Testes_10X_AAACCTGAGGTAAACT     18538     4310
# Antoine_Testes_10X_AAACCTGAGTACGTAA     35949     4131
# Antoine_Testes_10X_AAACCTGCAGTATGCT     17119     4054
# Antoine_Testes_10X_AAACCTGGTATAATGG     20283     4261
# Antoine_Testes_10X_AAACCTGGTGCCTGTG     49744     6391
#
#                                                               cell_id_v1  \
# Antoine_Testes_10X_AAACCTGAGGTAAACT  Antoine_Testes_10X_AAACCTGAGGTAAACT
# Antoine_Testes_10X_AAACCTGAGTACGTAA  Antoine_Testes_10X_AAACCTGAGTACGTAA
# Antoine_Testes_10X_AAACCTGCAGTATGCT  Antoine_Testes_10X_AAACCTGCAGTATGCT
# Antoine_Testes_10X_AAACCTGGTATAATGG  Antoine_Testes_10X_AAACCTGGTATAATGG
# Antoine_Testes_10X_AAACCTGGTGCCTGTG  Antoine_Testes_10X_AAACCTGGTGCCTGTG
#
#                                                               cell_id_v2  \
# Antoine_Testes_10X_AAACCTGAGGTAAACT  Antoine_Testes_10X_AAACCTGAGGTAAACT
# Antoine_Testes_10X_AAACCTGAGTACGTAA  Antoine_Testes_10X_AAACCTGAGTACGTAA
# Antoine_Testes_10X_AAACCTGCAGTATGCT  Antoine_Testes_10X_AAACCTGCAGTATGCT
# Antoine_Testes_10X_AAACCTGGTATAATGG  Antoine_Testes_10X_AAACCTGGTATAATGG
# Antoine_Testes_10X_AAACCTGGTGCCTGTG  Antoine_Testes_10X_AAACCTGGTGCCTGTG
#
#                                          cell_barcode  \
# Antoine_Testes_10X_AAACCTGAGGTAAACT  AAACCTGAGGTAAACT
# Antoine_Testes_10X_AAACCTGAGTACGTAA  AAACCTGAGTACGTAA
# Antoine_Testes_10X_AAACCTGCAGTATGCT  AAACCTGCAGTATGCT
# Antoine_Testes_10X_AAACCTGGTATAATGG  AAACCTGGTATAATGG
# Antoine_Testes_10X_AAACCTGGTGCCTGTG  AAACCTGGTGCCTGTG
#
#                                                     sequencing_run  \
# Antoine_Testes_10X_AAACCTGAGGTAAACT  180917_A00111_0212_BHGMF5DMXX
# Antoine_Testes_10X_AAACCTGAGTACGTAA  180917_A00111_0212_BHGMF5DMXX
# Antoine_Testes_10X_AAACCTGCAGTATGCT  180917_A00111_0212_BHGMF5DMXX
# Antoine_Testes_10X_AAACCTGGTATAATGG  180917_A00111_0212_BHGMF5DMXX
# Antoine_Testes_10X_AAACCTGGTGCCTGTG  180917_A00111_0212_BHGMF5DMXX
#
#                                                 channel  tissue subtissue  \
# Antoine_Testes_10X_AAACCTGAGGTAAACT  Antoine_Testes_10X  Testes       nan
# Antoine_Testes_10X_AAACCTGAGTACGTAA  Antoine_Testes_10X  Testes       nan
# Antoine_Testes_10X_AAACCTGCAGTATGCT  Antoine_Testes_10X  Testes       nan
# Antoine_Testes_10X_AAACCTGGTATAATGG  Antoine_Testes_10X  Testes       nan
# Antoine_Testes_10X_AAACCTGGTGCCTGTG  Antoine_Testes_10X  Testes       nan
#
#                                     cell_ontology_class  \
# Antoine_Testes_10X_AAACCTGAGGTAAACT        spermatocyte
# Antoine_Testes_10X_AAACCTGAGTACGTAA           spermatid
# Antoine_Testes_10X_AAACCTGCAGTATGCT        spermatocyte
# Antoine_Testes_10X_AAACCTGGTATAATGG        spermatocyte
# Antoine_Testes_10X_AAACCTGGTGCCTGTG        spermatocyte
#
#                                             free_annotation      species  \
# Antoine_Testes_10X_AAACCTGAGGTAAACT  pachytene spermatocyte  Mouse lemur
# Antoine_Testes_10X_AAACCTGAGTACGTAA         round spermatid  Mouse lemur
# Antoine_Testes_10X_AAACCTGCAGTATGCT  pachytene spermatocyte  Mouse lemur
# Antoine_Testes_10X_AAACCTGGTATAATGG  pachytene spermatocyte  Mouse lemur
# Antoine_Testes_10X_AAACCTGGTGCCTGTG  pachytene spermatocyte  Mouse lemur
#
#                                           species_latin   sex  age  \
# Antoine_Testes_10X_AAACCTGAGGTAAACT  Microcebus murinus  male  12y
# Antoine_Testes_10X_AAACCTGAGTACGTAA  Microcebus murinus  male  12y
# Antoine_Testes_10X_AAACCTGCAGTATGCT  Microcebus murinus  male  12y
# Antoine_Testes_10X_AAACCTGGTATAATGG  Microcebus murinus  male  12y
# Antoine_Testes_10X_AAACCTGGTGCCTGTG  Microcebus murinus  male  12y
#
#                                           individual
# Antoine_Testes_10X_AAACCTGAGGTAAACT  lemur_1_Antoine
# Antoine_Testes_10X_AAACCTGAGTACGTAA  lemur_1_Antoine
# Antoine_Testes_10X_AAACCTGCAGTATGCT  lemur_1_Antoine
# Antoine_Testes_10X_AAACCTGGTATAATGG  lemur_1_Antoine
# Antoine_Testes_10X_AAACCTGGTGCCTGTG  lemur_1_Antoine

# %% [markdown]
# ## Blood

# %%
import unified_annotations

blood_grouping = unified_annotations.get_celltype_converter('Blood', ("Lemur", "Tabula Microcebus", "free_annotation_update"))
print(blood_grouping.shape)
blood_grouping.head()
# Out:
# (28, 4)
#                                                    narrow_group  broad_group  \
# (Lemur, Tabula Microcebus, free_annotation_update)
# B cell                                                   B cell       B cell
# plasma cell                                         plasma cell  plasma cell
# T cell (CD4+ CD8- CCL5- CCR10+)                     CD4+ T cell       T cell
# T cell (CD4+ CD8- CCL5-)                            CD4+ T cell       T cell
# T cell (CD4- CD8+ CCL5+)                            CD8+ T cell       T cell
#
#                                                    compartment_group tissue
# (Lemur, Tabula Microcebus, free_annotation_update)
# B cell                                                      lymphoid  Blood
# plasma cell                                                 lymphoid  Blood
# T cell (CD4+ CD8- CCL5- CCR10+)                             lymphoid  Blood
# T cell (CD4+ CD8- CCL5-)                                    lymphoid  Blood
# T cell (CD4- CD8+ CCL5+)                                    lymphoid  Blood

# %% [markdown]
# ## Lung

# %%
lung_grouping = unified_annotations.get_celltype_converter('Lung', ("Lemur", "Tabula Microcebus", "free_annotation_update"))
print(lung_grouping.shape)
lung_grouping.head()
# Out:
# (0, 4)
# Empty DataFrame
# Columns: [narrow_group, broad_group, compartment_group, tissue]
# Index: []

# %% [markdown]
# ## Muscle

# %%
muscle_grouping = unified_annotations.get_celltype_converter('Muscle', ("Lemur", "Tabula Microcebus", "free_annotation_update"))
print(muscle_grouping.shape)
muscle_grouping.head()
# Out:
# (36, 4)
#                                                                  narrow_group  \
# (Lemur, Tabula Microcebus, free_annotation_update)
# B cell                                                                 B cell
# B cell (PF)                                              proliferating B cell
# plasma cell                                                       plasma cell
# plasma cell (PF)                                    proliferating plasma cell
# T cell (CD4+ CD8- CCL5- CLDN1+)                                   CD4+ T cell
#
#                                                     broad_group  \
# (Lemur, Tabula Microcebus, free_annotation_update)
# B cell                                                   B cell
# B cell (PF)                                              B cell
# plasma cell                                         plasma cell
# plasma cell (PF)                                    plasma cell
# T cell (CD4+ CD8- CCL5- CLDN1+)                          T cell
#
#                                                    compartment_group  tissue
# (Lemur, Tabula Microcebus, free_annotation_update)
# B cell                                                      lymphoid  Muscle
# B cell (PF)                                                 lymphoid  Muscle
# plasma cell                                                 lymphoid  Muscle
# plasma cell (PF)                                            lymphoid  Muscle
# T cell (CD4+ CD8- CCL5- CLDN1+)                             lymphoid  Muscle

# %% [markdown]
# ## Concatenate

# %%
grouping_concatenated = pd.concat([blood_grouping, muscle_grouping, lung_grouping])
grouping_concatenated = grouping_concatenated[["narrow_group", "broad_group", "compartment_group"]]
grouping_concatenated = grouping_concatenated.loc[~grouping_concatenated.index.duplicated()]
print(grouping_concatenated.shape)
grouping_concatenated.head()
# Out:
# (55, 3)
#                                                    narrow_group  broad_group  \
# (Lemur, Tabula Microcebus, free_annotation_update)
# B cell                                                   B cell       B cell
# plasma cell                                         plasma cell  plasma cell
# T cell (CD4+ CD8- CCL5- CCR10+)                     CD4+ T cell       T cell
# T cell (CD4+ CD8- CCL5-)                            CD4+ T cell       T cell
# T cell (CD4- CD8+ CCL5+)                            CD8+ T cell       T cell
#
#                                                    compartment_group
# (Lemur, Tabula Microcebus, free_annotation_update)
# B cell                                                      lymphoid
# plasma cell                                                 lymphoid
# T cell (CD4+ CD8- CCL5- CCR10+)                             lymphoid
# T cell (CD4+ CD8- CCL5-)                                    lymphoid
# T cell (CD4- CD8+ CCL5+)                                    lymphoid

# %% [markdown]
# ## Mege grouping with minimal obs

# %%
new_obs = obs_minimal.merge(grouping_concatenated, left_on='free_annotation', right_index=True, how='left')
print(new_obs.shape)
new_obs.head()
# Out:
# (231752, 19)
#                                      n_counts  n_genes  \
# Antoine_Testes_10X_AAACCTGAGGTAAAC
\
# Antoine_Testes_10X_AAACCTGAGGTAAACT  pachytene spermatocyte  Mouse lemur
# Antoine_Testes_10X_AAACCTGAGTACGTAA         round spermatid  Mouse lemur
# Antoine_Testes_10X_AAACCTGCAGTATGCT  pachytene spermatocyte  Mouse lemur
# Antoine_Testes_10X_AAACCTGGTATAATGG  pachytene spermatocyte  Mouse lemur
# Antoine_Testes_10X_AAACCTGGTGCCTGTG  pachytene spermatocyte  Mouse lemur
#
#                                           species_latin   sex  age  \
# Antoine_Testes_10X_AAACCTGAGGTAAACT  Microcebus murinus  male  12y
# Antoine_Testes_10X_AAACCTGAGTACGTAA  Microcebus murinus  male  12y
# Antoine_Testes_10X_AAACCTGCAGTATGCT  Microcebus murinus  male  12y
# Antoine_Testes_10X_AAACCTGGTATAATGG  Microcebus murinus  male  12y
# Antoine_Testes_10X_AAACCTGGTGCCTGTG  Microcebus murinus  male  12y
#
#                                           individual narrow_group broad_group  \
# Antoine_Testes_10X_AAACCTGAGGTAAACT  lemur_1_Antoine          NaN         NaN
# Antoine_Testes_10X_AAACCTGAGTACGTAA  lemur_1_Antoine          NaN         NaN
# Antoine_Testes_10X_AAACCTGCAGTATGCT  lemur_1_Antoine          NaN         NaN
# Antoine_Testes_10X_AAACCTGGTATAATGG  lemur_1_Antoine          NaN         NaN
# Antoine_Testes_10X_AAACCTGGTGCCTGTG  lemur_1_Antoine          NaN         NaN
#
#                                     compartment_group
# Antoine_Testes_10X_AAACCTGAGGTAAACT               NaN
# Antoine_Testes_10X_AAACCTGAGTACGTAA               NaN
# Antoine_Testes_10X_AAACCTGCAGTATGCT               NaN
# Antoine_Testes_10X_AAACCTGGTATAATGG               NaN
# Antoine_Testes_10X_AAACCTGGTGCCTGTG               NaN

# %% [markdown]
# ## Make new object with new metadata

# %%
lemur_tenx_new_obs = lemur_tenx.copy()
lemur_tenx_new_obs.obs = new_obs

# %% [markdown]
# # Write to file

# %%
h5ad = os.path.join(data_folder, "LCA_10x_update_minimal_obs.h5ad")
lemur_tenx_new_obs.write(h5ad)
# Out:
# ... storing 'free_annotation' as categorical
# ... storing 'narrow_group' as categorical
# ... storing 'broad_group' as categorical
# ... storing 'compartment_group' as categorical

# %%
lemur_tenx_new_obs.obs.individual.value_counts()
# Out:
# lemur_1_Antoine    96842
# lemur_4_Stumpy     83716
# lemur_3_Martine    30753
# lemur_2_Bernard    20441
# Name: individual, dtype: int64

# %%
h5ad
# Out:
# '/home/olga/data_lg/data_sm_copy/tabula-microcebus/data-objects/ss2-10x-combined/LCA_10x_update_minimal_obs.h5ad'

# %%
def check_celltype_presence(adata, celltypes=('alveolar fibroblast', 'skeletal muscle cell'), celltype_col='narrow_group'):
    for celltype in celltypes:
        assert celltype in set(adata.obs[celltype_col])

check_celltype_presence(lemur_tenx_new_obs)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-29-cd1b025bd3cb> in <module>
#       3         assert celltype in set(adata.obs[celltype_col])
#       4
# ----> 5 check_celltype_presence(lemur_tenx_new_obs)
#
# <ipython-input-29-cd1b025bd3cb> in check_celltype_presence(adata, celltypes, celltype_col)
#       1 def check_celltype_presence(adata, celltypes=('alveolar fibroblast', 'skeletal muscle cell'), celltype_col='narrow_group'):
#       2     for celltype in celltypes:
# ----> 3         assert celltype in set(adata.obs[celltype_col])
#       4
#       5 check_celltype_presence(lemur_tenx_new_obs)
#
# AssertionError:
